# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/My Thesis
# Out:
# /content/drive/MyDrive/My Thesis

# %%
# !git clone https://github.com/alexandrosstergiou/progressive-action-prediction
# Out:
# Cloning into 'progressive-action-prediction'...
# remote: Enumerating objects: 356, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 356 (delta 91), reused 172 (delta 77), pack-reused 166
# Receiving objects: 100% (356/356), 10.41 MiB | 14.25 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction/data
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/data

# %%
# !pip install unrar
# Out:
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
ls
# Out:
# __init__.py          jpgs2singlefile.py  num_frames.py  video_iterator.py  video_transforms.py
# iterator_factory.py  json_reader.py      UCF-101/       video_sampler.py

# %%
# !wget --no-check-certificate -O UCF101.rar "https://www.crcv.ucf.edu/data/UCF101/UCF101.rar"
# !unrar x UCF101.rar "/content/drive/MyDrive/My Thesis/progressive-action-prediction/data"
# !rm -f '/content/drive/MyDrive/My Thesis/progressive-action-prediction/data/UCF101.rar'

# %%
cd "/content/drive/MyDrive/My Thesis/progressive-action-prediction"
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
import os
# Count number of images
def count_videos_in_folder(folder_path):
    video_count = 0
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.avi'):
                video_count += 1
    return video_count

num_of_videos = count_videos_in_folder("/content/drive/MyDrive/My Thesis/progressive-action-prediction/data/UCF-101")
print(f'Total number of videos: {num_of_videos}')
# Out:
# Total number of videos: 1010

# %%
pip install "coloredlogs==14.0" "dataset2database==1.1" "einops==0.4.0" "ffmpeg-python==0.2.0" "imgaug==0.4.0" "opencv-python>=4.2.0.32" "ptflops==0.6.8" "torch" "torchinfo" "torchvision" "youtube-dl==2020.3.24" "timm" "fvcore" "pytorchvideo"
# Out:
# Collecting coloredlogs==14.0
#   Downloading coloredlogs-14.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 1.2 MB/s eta 0:00:00
# Collecting dataset2database==1.1
#   Downloading dataset2database-1.1-py3-none-any.whl (18 kB)
# Collecting einops==0.4.0
#   Downloading einops-0.4.0-py3-none-any.whl (28 kB)
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: imgaug==0.4.0 in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting ptflops==0.6.8
#   Downloading ptflops-0.6.8.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Collecting youtube-dl==2020.3.24
#   Downloading youtube_dl-2020.3.24-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.5 MB/s eta 0:00:00
# Collecting timm
#   Downloading timm-1.0.3-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 77.0 MB/s eta 0:00:00
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytorchvideo
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting humanfriendly>=7.1 (from coloredlogs==14.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python==0.2.0) (0.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (0.19.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0) (2.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.3)
# Collecting yacs>=0.1.6 (from fvcore)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore) (4.66.4)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore) (2.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo)
#   Downloading av-12.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 15.9 MB/s eta 0:00:00
# Collecting parameterized (from pytorchvideo)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2024.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0) (2.8.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Building wheels for collected packages: ptflops, fvcore, pytorchvideo, iopath
#   Building wheel for ptflops (setup.py) ... done
#   Created wheel for ptflops: filename=ptflops-0.6.8-py3-none-any.whl size=11851 sha256=6506b5c3bc30f11d6818e6ce73a41f0f3661344fce318d821f7692b1df727dc2
#   Stored in directory: /root/.cache/pip/wheels/65/78/dd/ee26db7b47fe0095e58d1020e16c93dc3ee6553e8547cc736c
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=5e113581fe416149c982e6676411703dad2ecb35b7255a5bd51521f3358b659e
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188685 sha256=55b013a8626a6070dbc7be4f57b77e79d431c930eaafc1b4f3f9750ba3164f4d
#   Stored in directory: /root/.cache/pip/wheels/ff/4e/81/0f72a543be9ed7eb737c95bfc5da4025e73226b44368074ece
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=cfc22cf0369544ddbf467c089181dbc882a1d17eb8bd072f93b19b01d17a6f6c
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built ptflops fvcore pytorchvideo iopath
# Installing collected packages: youtube-dl, einops, dataset2database, yacs, torchinfo, portalocker, parameterized, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, humanfriendly, ffmpeg-python, av, nvidia-cusparse-cu12, nvidia-cudnn-cu12, iopath, coloredlogs, nvidia-cusolver-cu12, fvcore, pytorchvideo, ptflops, timm
# Successfully installed av-12.0.0 coloredlogs-14.0 dataset2database-1.1 einops-0.4.0 ffmpeg-python-0.2.0 fvcore-0.1.5.post20221221 humanfriendly-10.0 iopath-0.1.10 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 parameterized-0.9.0 portalocker-2.8.2 ptflops-0.6.8 pytorchvideo-0.1.5 timm-1.0.3 torchinfo-1.8.0 yacs-0.1.8 youtube-dl-2020.3.24

# %%
# !pip install coloredlogs dataset2database einops ffmpeg-python imgaug opencv-python ptflops torch torchvision youtube-dl

# %%
import coloredlogs
import dataset2database
import einops
import ffmpeg
import imgaug
import cv2
import ptflops
import torch
import torchvision
import youtube_dl

print("coloredlogs:", coloredlogs.__version__)
# print("dataset2database:", dataset2database.__version__)
print("einops:", einops.__version__)
# print("ffmpeg-python:", ffmpeg.__version__)
print("imgaug:", imgaug.__version__)
print("opencv-python:", cv2.__version__)
# print("ptflops:", ptflops.__version__)
print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
# print("youtube-dl:", youtube_dl.__version__)
# Out:
# coloredlogs: 14.0
# einops: 0.4.0
# imgaug: 0.4.0
# opencv-python: 4.8.0
# torch: 2.2.1+cu121
# torchvision: 0.17.1+cu121

# %%
pip show dataset2database
# Out:
# Name: dataset2database
# Version: 1.1
# Summary: Script for creating SQL files from video files
# Home-page: https://github.com/alexandrosstergiou/dataset2database
# Author: Alexandros Stergiou
# Author-email: alexstergiou5@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
pip show ffmpeg-python
# Out:
# Name: ffmpeg-python
# Version: 0.2.0
# Summary: Python bindings for FFmpeg - with complex filtering support
# Home-page: https://github.com/kkroening/ffmpeg-python
# Author: Karl Kroening
# Author-email: karlk@kralnet.us
# License: UNKNOWN
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: future
# Required-by:

# %%
pip show ptflops
# Out:
# Name: ptflops
# Version: 0.6.8
# Summary: Flops counter for convolutional networks inpytorch framework
# Home-page: https://github.com/sovrasov/flops-counter.pytorch
# Author: Vladislav Sovrasov
# Author-email: sovrasov.vlad@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: torch
# Required-by:

# %%
pip show youtube-dl
# Out:
# Name: youtube-dl
# Version: 2020.3.24
# Summary: YouTube video downloader
# Home-page: https://github.com/ytdl-org/youtube-dl
# Author: Ricardo Garcia
# Author-email: ytdl@yt-dl.org
# License: Unlicense
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
# rm -rf adaPool

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
# !git clone https://github.com/alexandrosstergiou/adaPool.git
# Out:
# Cloning into 'adaPool'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 232 (delta 10), reused 4 (delta 2), pack-reused 210
# Receiving objects: 100% (232/232), 38.32 MiB | 10.82 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
cd adaPool/pytorch
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/adaPool/pytorch

# %%
# !make install
# Out:
# rm -rf *.egg-info
# rm -rf build dist
# python setup.py install
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating adaPool.egg-info
# writing adaPool.egg-info/PKG-INFO
# writing dependency_links to adaPool.egg-info/dependency_links.txt
# writing top-level names to adaPool.egg-info/top_level.txt
# writing manifest file 'adaPool.egg-info/SOURCES.txt'
# reading manifest file 'adaPool.egg-info/SOURCES.txt'
# writing manifest file 'adaPool.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/adaPool
# copying adaPool/__init__.py -> build/lib.linux-x86_64-cpython-310/adaPool
# copying adaPool/idea.py -> build/lib.linux-x86_64-cpython-310/adaPool
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:415: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:425: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'adapool_cuda' extension
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/CUDA
# x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c CUDA/adapool_cuda.cpp -o build/temp.linux-x86_64-cpython-310/CUDA/adapool_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=adapool_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/My Thesis/progressive-action-prediction/adaPool/pytorch/setup.py", line 4, in <module>
#     setup(
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/__init__.py", line 107, in setup
#     return distutils.core.setup(**attrs)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/core.py", line 185, in setup
#     return run_commands(dist)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/core.py", line 201, in run_commands
#     dist.run_commands()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#     self.run_command(cmd)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 1244, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py", line 988, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/install.py", line 80, in run
#     self.do_egg_install()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/install.py", line 129, in do_egg_install
#     self.run_command('bdist_egg')
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#     self.distribution.run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 1244, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py", line 988, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/bdist_egg.py", line 164, in run
#     cmd = self.call_command('install_lib', warn_dir=0)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/bdist_egg.py", line 150, in call_command
#     self.run_command(cmdname)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#     self.distribution.run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 1244, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py", line 988, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/install_lib.py", line 11, in run
#     self.build()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install_lib.py", line 111, in build
#     self.run_command('build_ext')
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#     self.distribution.run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/dist.py", line 1244, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py", line 988, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/build_ext.py", line 84, in run
#     _build_ext.run(self)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_ext.py", line 345, in run
#     self.build_extensions()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py", line 871, in build_extensions
#     build_ext.build_extensions(self)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_ext.py", line 467, in build_extensions
#     self._build_extensions_serial()
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_ext.py", line 493, in _build_extensions_serial
#     self.build_extension(ext)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/command/build_ext.py", line 246, in build_extension
#     _build_ext.build_extension(self, ext)
#   File "/usr/local/lib/python3.10/dist-packages/Cython/Distutils/build_ext.py", line 135, in build_extension
#     super(build_ext, self).build_extension(ext)
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_ext.py", line 548, in build_extension
#     objects = self.compiler.compile(
#   File "/usr/local/lib/python3.10/dist-packages/setuptools/_distutils/ccompiler.py", line 600, in compile
#     self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py", line 607, in unix_wrap_single_compile
#     cflags = unix_cuda_flags(cflags)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py", line 574, in unix_cuda_flags
#     cflags + _get_cuda_arch_flags(cflags))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py", line 1976, in _get_cuda_arch_flags
#     arch_list[-1] += '+PTX'
# IndexError: list index out of range
# make: *** [Makefile:2: install] Error 1

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels

# %%
# !wget --no-check-certificate -O /UCF101TrainTestSplits-RecognitionTask.zip "https://www.crcv.ucf.edu/data/UCF101/UCF101TrainTestSplits-RecognitionTask.zip"
# !unzip /UCF101TrainTestSplits-RecognitionTask.zip -d "/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels"
# !rm -f "/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF101TrainTestSplits-RecognitionTask.zip"
# Out:
# --2024-05-18 07:30:21--  https://www.crcv.ucf.edu/data/UCF101/UCF101TrainTestSplits-RecognitionTask.zip
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 113943 (111K) [application/zip]
# Saving to: ‘/UCF101TrainTestSplits-RecognitionTask.zip’
#
# /UCF101TrainTestSpl 100%[===================>] 111.27K  --.-KB/s    in 0.04s
#
# 2024-05-18 07:30:21 (2.93 MB/s) - ‘/UCF101TrainTestSplits-RecognitionTask.zip’ saved [113943/113943]
#
# Archive:  /UCF101TrainTestSplits-RecognitionTask.zip
#    creating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/classInd.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/testlist01.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/testlist02.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/testlist03.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/trainlist01.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/trainlist02.txt
#   inflating: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist/trainlist03.txt

# %%
# !mv '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/ucfTrainTestlist' '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101'

# %%
# !python label_format_conversion.py

# %%
# !mv '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/trainlist01.csv' '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/train.csv'
# !mv '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/testlist01.csv' '/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/test.csv'

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101

# %%
import pandas as pd
testdf = pd.read_csv("test.csv")
print(len(testdf))
testdf.tail()
# Out:
# 3783
#      label              id split
# 3778  YoYo  v_YoYo_g06_c04  test
# 3779  YoYo  v_YoYo_g07_c01  test
# 3780  YoYo  v_YoYo_g07_c02  test
# 3781  YoYo  v_YoYo_g07_c03  test
# 3782  YoYo  v_YoYo_g07_c04  test

# %%
traindf = pd.read_csv("train.csv")
print(len(traindf))
traindf.tail()
# Out:
# 9537
#      label              id  split
# 9532  YoYo  v_YoYo_g25_c01  train
# 9533  YoYo  v_YoYo_g25_c02  train
# 9534  YoYo  v_YoYo_g25_c03  train
# 9535  YoYo  v_YoYo_g25_c04  train
# 9536  YoYo  v_YoYo_g25_c05  train

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the training data
train_df = pd.read_csv('/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/train.csv')

# Split the data: 80% train, 20% validation
train_data, val_data = train_test_split(train_df, test_size=0.2, random_state=42)

# Save the splits
train_data.to_csv('/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/train.csv', index=False)
val_data.to_csv('/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/val.csv', index=False)

# %%
cd "/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/"
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101

# %%
traindf = pd.read_csv("train.csv")
print(len(traindf))
traindf.tail()
# Out:
# 7629
#                label                        id  split
# 7624     PlayingDhol     v_PlayingDhol_g08_c01  train
# 7625    MoppingFloor    v_MoppingFloor_g12_c02  train
# 7626    ParallelBars    v_ParallelBars_g17_c03  train
# 7627  BasketballDunk  v_BasketballDunk_g23_c02  train
# 7628       SalsaSpin       v_SalsaSpin_g11_c05  train

# %%
valdf = pd.read_csv("val.csv")
print(len(valdf))
valdf.tail()
# Out:
# 1908
#                label                        id  split
# 1903          Skiing          v_Skiing_g11_c01  train
# 1904      PlayingDaf      v_PlayingDaf_g15_c01  train
# 1905      IceDancing      v_IceDancing_g12_c07  train
# 1906  MilitaryParade  v_MilitaryParade_g10_c01  train
# 1907  ApplyEyeMakeup  v_ApplyEyeMakeup_g23_c01  train

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
mkdir weights

# %%
cd weights
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction/weights

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown

# https://drive.google.com/file/d/12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J/view?usp=sharing"
file_id = '12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J'
url = f'https://drive.google.com/uc?id={file_id}'
output = "/content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J
# From (redirected): https://drive.google.com/uc?id=12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J&confirm=t&uuid=35c51307-2599-45ec-83dd-d64890dbf668
# To: /content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth
# 100%|██████████| 156M/156M [00:11<00:00, 14.0MB/s]
# '/content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth'

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
import gdown
file_id = '1vYqmTEBIYrAH4omII7vA3ZtUjoqTb5F0'
url = f'https://drive.google.com/uc?id={file_id}'
output = "/content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vYqmTEBIYrAH4omII7vA3ZtUjoqTb5F0
# From (redirected): https://drive.google.com/uc?id=1vYqmTEBIYrAH4omII7vA3ZtUjoqTb5F0&confirm=t&uuid=b6732bbc-5555-4362-ae0c-be0166233143
# To: /content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth
# 100%|██████████| 156M/156M [00:05<00:00, 27.8MB/s]
# '/content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth'

# %% [markdown]
# Train on UCF-101 with observation ratio 0.3, 3 scales, with movinet backbone, with the pretrained UCF-101 backbone checkpoint stored in weights, and over 4 gpu

# %%
cd "/content/drive/MyDrive/My Thesis/progressive-action-prediction"
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
ls
# Out:
# adaPool/  dataset.py    labels/  network/      results/                        train.py
# config/   figures/      LICENSE  __pycache__/  run/                            weights/
# data/     inference.py  logs/    README.md     Tempr_h_movinet_ada_obs_03.pth

# %%
# !python train.py --video_per 0.3 --num_samplers 3 --gpus 0 --precision mixed --dataset UCF-101 --frame_size 224 --batch_size 2 --data_dir "/content/drive/MyDrive/My Thesis/progressive-action-prediction/data/UCF-101" --label_dir "/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101" --workers 2 --backbone movinet --end_epoch 2 --pretrained_dir "/content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth"
# Out:
# 2024-05-19 07:47:09 05816b2c91cc root[9005] INFO CUDA_VISIBLE_DEVICES set to 0
# 2024-05-19 07:47:09 05816b2c91cc root[9005] INFO Using pytorch version 2.2.1+cu121 (['/usr/local/lib/python3.10/dist-packages/torch'])
# 2024-05-19 07:47:09 05816b2c91cc root[9005] INFO Start training with args:
# {
#     "accum_grads": 1,
#     "attn_dropout": 0.0,
#     "backbone": "movinet",
#     "batch_size": 2,
#     "config": null,
#     "cross_dim_head": 64,
#     "cross_heads": 1,
#     "data_dir": "/content/drive/MyDrive/My Thesis/progressive-action-prediction/data/UCF-101",
#     "dataset": "UCF-101",
#     "end_epoch": 2,
#     "ff_dropout": 0.0,
#     "frame_len": 16,
#     "frame_size": "224",
#     "gpus": [
#         0
#     ],
#     "head": "Tempr_h",
#     "label_dir": "/content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101",
#     "latent_dim": 512,
#     "latent_dim_head": 64,
#     "latent_heads": 8,
#     "log_file": "logs/video_pred_at-05816b2c91cc_datetime_2024-5-19_with_observation_ratio_0.3_Tempr_h_movinet_ada.log",
#     "long_cycles": false,
#     "lr_base": 0.01,
#     "lr_factor": 0.1,
#     "lr_mult": {
#         "classifier": 1.0,
#         "head": 0.1,
#         "pool": 0.1
#     },
#     "lr_steps": [
#         14,
#         32,
#         44
#     ],
#     "max_freq": 10.0,
#     "model_dir": "./results/observation_ratio_0.3/Tempr_h_movinet_ada",
#     "num_freq_bands": 10,
#     "num_latents": 256,
#     "num_samplers": 3,
#     "optimiser": "AdamW",
#     "pool": "ada",
#     "precision": "mixed",
#     "pretrained_dir": "/content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth",
#     "print_net": false,
#     "random_seed": 1,
#     "results_dir": "./results",
#     "resume_epoch": 0,
#     "save_frequency": 1,
#     "short_cycles": false,
#     "train_frame_interval": [
#         1,
#         2,
#         3,
#         4
#     ],
#     "use_frames": false,
#     "val_frame_interval": [
#         1,
#         2
#     ],
#     "video_per": 0.3,
#     "video_per_train": 0.4,
#     "video_per_val": 0.4,
#     "weight_decay": 1e-05,
#     "weight_tie_layers": false,
#     "workers": 2
# }
# 2024-05-19 07:47:09 05816b2c91cc root[9005] INFO CUDA availability: True
# 2024-05-19 07:47:09 05816b2c91cc root[9005] INFO Preprocessing:: using default mean & std.
#
# 2024-05-19 07:47:14 05816b2c91cc root[9005] INFO VideoIter:: - Found: 707/706 videos from csv file
# 2024-05-19 07:47:14 05816b2c91cc root[9005] INFO VideoIter:: Found dict at: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/dictionary.json
#
# 2024-05-19 07:47:14 05816b2c91cc root[9005] INFO VideoIter:: iterator initialized (phase: 'train', num: 707)
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO VideoIter:: - Found: 151/150 videos from csv file
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO VideoIter:: Found dict at: /content/drive/MyDrive/My Thesis/progressive-action-prediction/labels/UCF-101/dictionary.json
#
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO VideoIter:: iterator initialized (phase: 'val', num: 151)
#
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO Optimiser:: - classifier lr is set to 1.0e-2 for 190 params
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO Optimiser:: - head lr is set to 1.0e-3 for 81 params
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO Optimiser:: - pool lr is set to 1.0e-3 for 1 params
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO Optimiser:: - base lr is set to 1.0e-02 for 760 params
#
# 2024-05-19 07:47:15 05816b2c91cc root[9005] INFO IterScheduler:: Each epoch will have 353 iterations based on batch size 2
# 2024-05-19 07:47:40 05816b2c91cc root[9005] WARNING Initialiser:: The following keys were not used: ['module.head.layers.3.0.fn.to_q.weight', 'module.head.layers.3.0.fn.to_kv.weight', 'module.head.layers.3.0.fn.to_out.0.weight', 'module.head.layers.3.0.fn.to_out.0.bias', 'module.head.layers.3.0.norm.weight', 'module.head.layers.3.0.norm.bias', 'module.head.layers.3.0.norm_context.weight', 'module.head.layers.3.0.norm_context.bias', 'module.head.layers.3.1.fn.net.0.weight', 'module.head.layers.3.1.fn.net.0.bias', 'module.head.layers.3.1.fn.net.3.weight', 'module.head.layers.3.1.fn.net.3.bias', 'module.head.layers.3.1.norm.weight', 'module.head.layers.3.1.norm.bias', 'module.head.layers.3.2.0.0.fn.to_q.weight', 'module.head.layers.3.2.0.0.fn.to_kv.weight', 'module.head.layers.3.2.0.0.fn.to_out.0.weight', 'module.head.layers.3.2.0.0.fn.to_out.0.bias', 'module.head.layers.3.2.0.0.norm.weight', 'module.head.layers.3.2.0.0.norm.bias', 'module.head.layers.3.2.0.1.fn.net.0.weight', 'module.head.layers.3.2.0.1.fn.net.0.bias', 'module.head.layers.3.2.0.1.fn.net.3.weight', 'module.head.layers.3.2.0.1.fn.net.3.bias', 'module.head.layers.3.2.0.1.norm.weight', 'module.head.layers.3.2.0.1.norm.bias']
# 2024-05-19 07:47:40 05816b2c91cc root[9005] WARNING Initialiser:: Did not load optimiser state from: `/content/drive/MyDrive/My Thesis/progressive-action-prediction/weights/movinet_ada_best.pth'
# 2024-05-19 07:47:40 05816b2c91cc root[9005] INFO Iter 0: start with learning rate: 1.00000e-02 (next lr step: 4942)
# 2024-05-19 07:47:40 05816b2c91cc root[9005] INFO LRScheduler: The learning rate will change at steps: [4942, 11296, 15532]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 2024-05-19 07:48:12 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [000/353] Speed (r : 9.89e-2 f : 1.73e-1 b : 3.71e+0) clip/sec  loss-ce : 1.2178, top1 : 0.5000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:12 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [001/353] Speed (r : 2.07e+1 f : 5.50e+0 b : 1.44e+1) clip/sec  loss-ce : 7.0145, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:14 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [002/353] Speed (r : 1.72e+1 f : 3.56e+0 b : 4.22e+0) clip/sec  loss-ce : 1.3324, top1 : 0.5000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:15 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [003/353] Speed (r : 1.68e+1 f : 2.52e+0 b : 2.50e+1) clip/sec  loss-ce : 5.1939, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:15 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [004/353] Speed (r : 1.71e+1 f : 3.40e+0 b : 4.67e+1) clip/sec  loss-ce : 4.4314, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:16 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [005/353] Speed (r : 2.13e+1 f : 3.16e+0 b : 3.32e+1) clip/sec  loss-ce : 5.2517, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:17 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [006/353] Speed (r : 1.85e+1 f : 2.88e+0 b : 3.26e+1) clip/sec  loss-ce : 7.5329, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:18 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [007/353] Speed (r : 1.39e+1 f : 2.54e+0 b : 2.94e+1) clip/sec  loss-ce : 6.7918, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:19 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [008/353] Speed (r : 1.70e+1 f : 2.40e+0 b : 2.05e+1) clip/sec  loss-ce : 5.3944, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:20 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [009/353] Speed (r : 1.44e+1 f : 1.92e+0 b : 1.95e+1) clip/sec  loss-ce : 5.1913, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:22 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [010/353] Speed (r : 7.87e+0 f : 2.08e+0 b : 2.69e+1) clip/sec  loss-ce : 3.9721, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:23 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [011/353] Speed (r : 1.43e+1 f : 2.91e+0 b : 3.13e+1) clip/sec  loss-ce : 4.2199, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:24 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [012/353] Speed (r : 1.45e+1 f : 3.31e+0 b : 1.95e+1) clip/sec  loss-ce : 1.4033, top1 : 0.5000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:25 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [013/353] Speed (r : 1.36e+1 f : 1.36e+0 b : 1.71e+1) clip/sec  loss-ce : 3.2948, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:28 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [014/353] Speed (r : 7.14e+0 f : 1.06e+0 b : 1.10e+1) clip/sec  loss-ce : 9.4196, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:30 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [015/353] Speed (r : 8.27e+0 f : 1.22e+0 b : 1.74e+1) clip/sec  loss-ce : 5.9588, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:32 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [016/353] Speed (r : 7.37e+0 f : 1.27e+0 b : 1.12e+1) clip/sec  loss-ce : 5.7232, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:34 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [017/353] Speed (r : 7.51e+0 f : 1.11e+0 b : 1.35e+1) clip/sec  loss-ce : 4.5927, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:36 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [018/353] Speed (r : 7.15e+0 f : 1.12e+0 b : 9.18e+0) clip/sec  loss-ce : 4.2131, top1 : 0.0000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:39 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [019/353] Speed (r : 6.50e+0 f : 1.14e+0 b : 1.29e+1) clip/sec  loss-ce : 1.3942, top1 : 0.0000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:41 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [020/353] Speed (r : 7.03e+0 f : 1.17e+0 b : 1.30e+1) clip/sec  loss-ce : 5.7081, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:43 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [021/353] Speed (r : 6.63e+0 f : 1.23e+0 b : 1.58e+1) clip/sec  loss-ce : 3.4653, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:45 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [022/353] Speed (r : 7.17e+0 f : 1.14e+0 b : 1.04e+1) clip/sec  loss-ce : 4.9361, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:47 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [023/353] Speed (r : 9.86e+0 f : 2.11e+0 b : 2.19e+1) clip/sec  loss-ce : 5.5981, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:48 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [024/353] Speed (r : 1.23e+1 f : 2.01e+0 b : 1.90e+1) clip/sec  loss-ce : 3.7979, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:49 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [025/353] Speed (r : 1.47e+1 f : 2.91e+0 b : 2.88e+1) clip/sec  loss-ce : 7.2864, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:50 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [026/353] Speed (r : 1.06e+1 f : 2.33e+0 b : 2.14e+1) clip/sec  loss-ce : 10.1028, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:51 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [027/353] Speed (r : 1.37e+1 f : 1.94e+0 b : 2.48e+1) clip/sec  loss-ce : 5.0078, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:52 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [028/353] Speed (r : 1.40e+1 f : 2.31e+0 b : 2.86e+1) clip/sec  loss-ce : 3.4182, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:53 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [029/353] Speed (r : 1.69e+1 f : 2.25e+0 b : 1.83e+1) clip/sec  loss-ce : 3.2558, top1 : 0.0000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:55 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [030/353] Speed (r : 1.34e+1 f : 2.39e+0 b : 1.68e+1) clip/sec  loss-ce : 6.0198, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:56 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [031/353] Speed (r : 1.21e+1 f : 1.98e+0 b : 2.01e+1) clip/sec  loss-ce : 4.8957, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:48:58 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [032/353] Speed (r : 7.70e+0 f : 1.22e+0 b : 1.64e+1) clip/sec  loss-ce : 3.4169, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:00 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [033/353] Speed (r : 6.99e+0 f : 1.31e+0 b : 8.50e+0) clip/sec  loss-ce : 5.0333, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:02 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [034/353] Speed (r : 7.16e+0 f : 1.17e+0 b : 1.34e+1) clip/sec  loss-ce : 2.9105, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:04 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [035/353] Speed (r : 6.39e+0 f : 1.19e+0 b : 1.34e+1) clip/sec  loss-ce : 1.9411, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:06 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [036/353] Speed (r : 7.21e+0 f : 1.37e+0 b : 1.25e+1) clip/sec  loss-ce : 5.4981, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:08 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [037/353] Speed (r : 7.77e+0 f : 2.20e+0 b : 2.08e+1) clip/sec  loss-ce : 6.5075, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:09 05816b2c91cc root[9005] INFO Epoch [0/2] Batch [038/353] Speed (r : 1.43e+1 f : 2.31e+0 b : 2.30e+1) clip/sec  loss-ce : 5.2679, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 07:49:10 05816b2c91cc root[9005] INFO Epoch [0/2] Batch
05816b2c91cc root[9005] INFO Epoch [1/2] Batch [338/353] Speed (r : 1.49e+1 f : 3.83e+0 b : 1.73e+1) clip/sec  loss-ce : 3.9176, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:21 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [339/353] Speed (r : 1.47e+1 f : 3.07e+0 b : 2.89e+1) clip/sec  loss-ce : 5.0572, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:22 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [340/353] Speed (r : 2.94e+1 f : 5.89e+0 b : 3.92e+1) clip/sec  loss-ce : 4.2437, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:22 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [341/353] Speed (r : 3.29e+1 f : 4.38e+0 b : 4.01e+1) clip/sec  loss-ce : 1.8211, top1 : 0.0000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:23 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [342/353] Speed (r : 2.63e+1 f : 4.51e+0 b : 4.98e+1) clip/sec  loss-ce : 2.4877, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:23 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [343/353] Speed (r : 2.61e+1 f : 6.01e+0 b : 5.06e+1) clip/sec  loss-ce : 6.7884, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:24 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [344/353] Speed (r : 3.96e+1 f : 9.19e+0 b : 2.87e+1) clip/sec  loss-ce : 2.6830, top1 : 0.0000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:24 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [345/353] Speed (r : 6.38e+1 f : 9.20e+0 b : 3.08e+1) clip/sec  loss-ce : 4.2058, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:24 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [346/353] Speed (r : 6.13e+1 f : 9.10e+0 b : 3.07e+1) clip/sec  loss-ce : 3.6460, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:24 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [347/353] Speed (r : 7.35e+1 f : 9.35e+0 b : 3.07e+1) clip/sec  loss-ce : 4.3947, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:25 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [348/353] Speed (r : 6.60e+1 f : 9.12e+0 b : 2.96e+1) clip/sec  loss-ce : 4.4938, top1 : 0.0000, top5 : 0.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:25 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [349/353] Speed (r : 6.81e+1 f : 9.09e+0 b : 3.04e+1) clip/sec  loss-ce : 2.3035, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:25 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [350/353] Speed (r : 6.12e+1 f : 9.27e+0 b : 3.08e+1) clip/sec  loss-ce : 4.6364, top1 : 0.5000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:26 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [351/353] Speed (r : 7.08e+1 f : 9.29e+0 b : 3.07e+1) clip/sec  loss-ce : 3.8549, top1 : 0.0000, top5 : 0.5000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:26 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [352/353] Speed (r : 7.42e+1 f : 9.35e+0 b : 3.07e+1) clip/sec  loss-ce : 2.4175, top1 : 0.5000, top5 : 1.0000, batch size : (  2,3,3,16,244,244), lr : 1.00e-2
# 2024-05-19 08:07:27 05816b2c91cc root[9005] INFO Epoch [1]   time cost: 565.4095 sec (0.1571 h)
# 2024-05-19 08:07:27 05816b2c91cc root[9005] INFO Epoch [1]  (train)  average top-1 acc: 0.24504   average top-5 acc: 0.54533   average loss: 3.35991
# 2024-05-19 08:07:27 05816b2c91cc root[9005] INFO Start evaluating epoch 1:
# 2024-05-19 08:07:33 05816b2c91cc root[9005] INFO Epoch [1]: Iteration [0]:  (val)  average top-1 acc: 0.00000   average top-5 acc: 0.00000   average loss 4.99914
# 2024-05-19 08:07:54 05816b2c91cc root[9005] INFO Epoch [1]: Iteration [20]:  (val)  average top-1 acc: 0.53098   average top-5 acc: 0.77319   average loss 2.06768
# 2024-05-19 08:08:10 05816b2c91cc root[9005] INFO Epoch [1]: Iteration [40]:  (val)  average top-1 acc: 0.55579   average top-5 acc: 0.81157   average loss 1.83970
# 2024-05-19 08:08:20 05816b2c91cc root[9005] INFO Epoch [1]: Iteration [60]:  (val)  average top-1 acc: 0.57697   average top-5 acc: 0.83408   average loss 1.70520
# 2024-05-19 08:08:25 05816b2c91cc root[9005] INFO Epoch [1/2] Batch [074/353] Speed (r : 1.17e-9 f : 9.55e+0 b : 3.07e+1) clip/sec  loss-ce : 1.4745, top1 : 0.5733, top5 : 0.8867,
# 2024-05-19 08:08:25 05816b2c91cc root[9005] INFO Epoch [1]:  (val)  average top-1 acc: 0.57818   average top-5 acc: 0.84245   average loss 1.66575
# 2024-05-19 08:08:26 05816b2c91cc root[9005] INFO --- Finished ---

# %%
# Open file: /usr/local/lib/python3.10/dist-packages/pytorchvideo/transforms/augmentations.py
# # Change
# import torchvision.transforms.functional_tensor as F_t
# # to
# from torchvision.transforms import functional as F_t
# line 9

# Not find weights/UCF-101/movinet_ada_best.pth, I get checkpoint from after training with tempr is true or fail
# Any solution for this problem

# %% [markdown]
# Run inference

# %%
cd /content/drive/MyDrive/My Thesis/progressive-action-prediction
# Out:
# /content/drive/MyDrive/My Thesis/progressive-action-prediction

# %%
ls
# Out:
# adaPool/  dataset.py    labels/  network/      results/                        train.py
# config/   figures/      LICENSE  __pycache__/  run/                            weights/
# data/     inference.py  logs/    README.md     Tempr_h_movinet_ada_obs_03.pth

# %%
# !python inference.py --config config/inference/smthng-smthng/config.yml --head TemPr_h --pool ada --gpus 0 --chkp "Tempr_h_movinet_ada_obs_03.pth"

# %%
import gdown

# https://drive.google.com/file/d/12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J/view?usp=sharing"
file_id = '12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J'
url = f'https://drive.google.com/uc?id={file_id}'
output = "/content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J
# From (redirected): https://drive.google.com/uc?id=12IEDxnZ8WS1f0eoN_CnEMYq1Lig4uZ8J&confirm=t&uuid=136708c2-0495-4433-a826-c85e879396a4
# To: /content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth
# 100%|██████████| 156M/156M [00:03<00:00, 39.9MB/s]
# '/content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth'

# %%
ls
# Out:
# adaPool/  dataset.py    labels/  network/      results/                        train.py
# config/   figures/      LICENSE  __pycache__/  run/                            weights/
# data/     inference.py  logs/    README.md     Tempr_h_movinet_ada_obs_03.pth

# %%
# !python inference.py --config "/content/drive/MyDrive/My Thesis/progressive-action-prediction/config/inference/UCF-101/config.yml" --head TemPr_h --pool ada --gpus 0 --chkp "/content/drive/MyDrive/My Thesis/progressive-action-prediction/Tempr_h_movinet_ada_obs_03.pth"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/My Thesis/progressive-action-prediction/inference.py", line 10, in <module>
#     import coloredlogs, logging
# ModuleNotFoundError: No module named 'coloredlogs'
